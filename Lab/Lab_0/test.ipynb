# %%
print("Hello world")
# This is a sample Python script.
# Out:
# Hello world

# %% [markdown]
# # Devoir 0
#
# The idea is to learn how to apply and use Hupyter so that we are ready for the next step
